# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithishkumar2867/python-machine-learning/blob/main/enginerring_features2_067.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing pandas and numpy libraries

import pandas as pd

import numpy as np

#Creating a dummy DataFrame of 12 numbers randomly

#ranging from 150-180 for height

df = pd.DataFrame({'Height': [150.4, 157.6, 170, 176, 164.2, 155,

159.2, 175, 162.4, 176, 153, 170.9]})

#Printing DataFrame Before Sorting Continuous to Categories

print("Before: ")

print(df)

# A column of name 'Label' is created in DataFrame

#Categorizing Height into 3 Categories

#Short: (150,157), 150 is excluded & 157 is included

#Average: (157,169), 157 is excluded & 169 is included

#Tall: (169,180], 169 is excluded & 180 is included

df['Label'] = pd.cut(x=df['Height'],

bins=[150, 157, 169, 180],

labels=['Short', 'Average', 'Tall'])

#Printing DataFrame After Sorting Continuous to Categories

print("After: ")

print(df)

#Check the number of values in each bin

print("Categories: ")

print(df['Label'].value_counts())
# Out:
# Before:
#     Height
# 0    150.4
# 1    157.6
# 2    170.0
# 3    176.0
# 4    164.2
# 5    155.0
# 6    159.2
# 7    175.0
# 8    162.4
# 9    176.0
# 10   153.0
# 11   170.9
# After:
#     Height    Label
# 0    150.4    Short
# 1    157.6  Average
# 2    170.0     Tall
# 3    176.0     Tall
# 4    164.2  Average
# 5    155.0    Short
# 6    159.2  Average
# 7    175.0     Tall
# 8    162.4  Average
# 9    176.0     Tall
# 10   153.0    Short
# 11   170.9     Tall
# Categories:
# Label
# Tall       5
# Average    4
# Short      3
# Name: count, dtype: int64
