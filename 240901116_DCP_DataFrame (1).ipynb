# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a  0.278837  0.688230 -1.373749
# b       NaN       NaN       NaN
# c -1.539887  0.350424 -0.248605
# d  1.189316  1.012393  1.155673
# e       NaN       NaN       NaN
# f  0.976750  0.177974  0.297761
#
#
# Dropped DataFrame
#          one       two     three
# a  0.278837  0.688230 -1.373749
# c -1.539887  0.350424 -0.248605
# d  1.189316  1.012393  1.155673
# f  0.976750  0.177974  0.297761

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.066651  0.674934 -1.184446
# b       NaN       NaN       NaN
# c -0.032450  1.731251 -0.642708
#
#
# NaN replaced with '0':
#
#         one       two     three
# a -0.066651  0.674934 -1.184446
# b  0.000000  0.000000  0.000000
# c -0.032450  1.731251 -0.642708

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  1.157260  0.329244  1.289813
# b       NaN       NaN       NaN
# c  0.808222 -1.308589 -0.268345
# d -2.346878 -0.352886 -0.603695
# e       NaN       NaN       NaN
# f -0.062664  0.429991 -0.984584
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],
                columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.bfill())
# Out:
# Original Dataframe:
#          one       two     three
# a  1.913449 -0.294376  0.111319
# b       NaN       NaN       NaN
# c -1.486714 -1.201977  0.268303
# d -0.011341 -1.224972  0.425392
# e       NaN       NaN       NaN
# f -1.438601  0.325727  0.178981
#
# NaN - Filled with Background values:
#
#         one       two     three
# a  1.913449 -0.294376  0.111319
# b -1.486714 -1.201977  0.268303
# c -1.486714 -1.201977  0.268303
# d -0.011341 -1.224972  0.425392
# e -1.438601  0.325727  0.178981
# f -1.438601  0.325727  0.178981
