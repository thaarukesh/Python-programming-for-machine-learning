# %%
import pandas as pd
pd.set_option('display.max_columns',10)
print("Original data:\n")
df=pd.read_excel("C:\\Users\\DELL\\Downloads\\II EEE marks.xlsx")
print(df)
# Out:
# Original data:
#
#    S.No Student Name   Eng  Maths  Phy  Che  Bio  Tamil
# 0     1           Aja   95     96   99   98   96     92
# 1     2         Bison   95     96   58   68   82     25
# 2     3           Cat   63     45   99   98   51     38
# 3     4          Dany    9     85   99   56   89     45
# 4     5         Eliza    6     78   99   58   64     67
# 5     6          Fijo   95     96   99   59   73     92
# 6     7          Gani   94     45   99    2   85     87
# 7     8          Hari   95     96   99    8   96     92
# 8     9         Iniya   58     59   99   98   34     78
# 9    10          Jack   95     96   99   98   96     59

# %%
import pandas as pd
pd.set_option('display.max_columns',10)
print("Original data:\n")
df=pd.read_excel("C:\\Users\\DELL\\Downloads\\II EEE marks.xlsx")
print(df)
print("\nDrop one particular column and its values: \n")
df.drop(['Tamil'], axis=1,inplace=True)
print(df)
print("\nUpdated list..\n")
df.to_excel("C:\\Users\\DELL\\Downloads\\II EEE marks.xlsx")
# Out:
# Original data:
#
#    S.No Student Name   Eng  Maths  Phy  Che  Bio  Tamil
# 0     1           Aja   95     96   99   98   96     92
# 1     2         Bison   95     96   58   68   82     25
# 2     3           Cat   63     45   99   98   51     38
# 3     4          Dany    9     85   99   56   89     45
# 4     5         Eliza    6     78   99   58   64     67
# 5     6          Fijo   95     96   99   59   73     92
# 6     7          Gani   94     45   99    2   85     87
# 7     8          Hari   95     96   99    8   96     92
# 8     9         Iniya   58     59   99   98   34     78
# 9    10          Jack   95     96   99   98   96     59
#
# Drop one particular column and its values:
#
#    S.No Student Name   Eng  Maths  Phy  Che  Bio
# 0     1           Aja   95     96   99   98   96
# 1     2         Bison   95     96   58   68   82
# 2     3           Cat   63     45   99   98   51
# 3     4          Dany    9     85   99   56   89
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns',10)
print("Original data:\n")
df=pd.read_excel("C:\\Users\\DELL\\Downloads\\II EEE marks.xlsx")
print(df)
print("\nDrop NaN rows:\n")
df=pd.read_excel("C:\\Users\\DELL\\Downloads\\II EEE marks.xlsx")
print(df)
x=df.dropna()
print(x)
print("\nUpdated data list:\n")
x.to_excel("C:\\Users\\DELL\\Downloads\\II EEE marks.xlsx")
# Out:
# Original data:
#
#    Unnamed: 0  S.No Student Name   Eng  Maths  Phy  Che  Bio
# 0           0     1           Aja   95     96   99   98   96
# 1           1     2         Bison   95     96   58   68   82
# 2           2     3           Cat   63     45   99   98   51
# 3           3     4          Dany    9     85   99   56   89
# 4           4     5         Eliza    6     78   99   58   64
# 5           5     6          Fijo   95     96   99   59   73
# 6           6     7          Gani   94     45   99    2   85
# 7           7     8          Hari   95     96   99    8   96
# 8           8     9         Iniya   58     59   99   98   34
# 9           9    10          Jack   95     96   99   98   96
#
# Drop NaN rows:
#
#    Unnamed: 0  S.No Student Name   Eng  Maths  Phy  Che  Bio
# 0           0     1           Aja   95     96   99   98   96
# 1           1     2         Bison   95     96   58   68   82
# 2           2     3           Cat   63     45   99   98   51
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns',10)
print("Original data:\n")
df=pd.read_excel("C:\\Users\\DELL\\Downloads\\II EEE marks.xlsx")
print(df)
print("\nReplace values:\n")
n=pd.read_excel("C:\\Users\\DELL\\Downloads\\II EEE marks.xlsx")
print("\nOriginal data:\n")
print(n)
y=n.replace({89:88})
print("\nReplaced dataset:\n")
print(y)
print("\nUpdated dataset:\n")
y.to_excel("C:\\Users\\DELL\\Downloads\\II EEE marks.xlsx")
# Out:
# Original data:
#
#    Unnamed: 0.1  Unnamed: 0  S.No Student Name   Eng  Maths  Phy  Che  Bio
# 0             0           0     1           Aja   95     96   99   98   96
# 1             1           1     2         Bison   95     96   58   68   82
# 2             2           2     3           Cat   63     45   99   98   51
# 3             3           3     4          Dany    9     85   99   56   89
# 4             4           4     5         Eliza    6     78   99   58   64
# 5             5           5     6          Fijo   95     96   99   59   73
# 6             6           6     7          Gani   94     45   99    2   85
# 7             7           7     8          Hari   95     96   99    8   96
# 8             8           8     9         Iniya   58     59   99   98   34
# 9             9           9    10          Jack   95     96   99   98   96
#
# Replace values:
#
#
# Original data:
#
#    Unnamed: 0.1  Unnamed: 0  S.No Student Name   Eng  Maths  Phy  Che  Bio
# ...

# %%
df=pd.read_excel("C:\\Users\\DELL\\Downloads\\II EEE marks.xlsx")
print(df)
print("\nExtract using isin() function:\n")
new=df['Eng'].isin([88])
print(df[new])
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  S.No Student Name   Eng  Maths  \
# 0             0             0           0     1           Aja   95     96
# 1             1             1           1     2         Bison   95     96
# 2             2             2           2     3           Cat   63     45
# 3             3             3           3     4          Dany    9     85
# 4             4             4           4     5         Eliza    6     78
# 5             5             5           5     6          Fijo   95     96
# 6             6             6           6     7          Gani   94     45
# 7             7             7           7     8          Hari   95     96
# 8             8             8           8     9         Iniya   58     59
# 9             9             9           9    10          Jack   95     96
#
#    Phy  Che  Bio
# 0   99   98   96
# 1   58   68   82
# 2   99   98   51
# 3   99   56   88
# 4   99   58   64
# 5   99   59   73
# 6   99    2   85
# ...
